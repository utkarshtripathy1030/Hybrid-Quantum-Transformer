# %%
# !git clone https://github.com/utkarshtripathy1030/Hybrid-Quantum-Transformer.git
# %cd Hybrid-Quantum-Transformer
# Out:
# Cloning into 'Hybrid-Quantum-Transformer'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 44 (delta 18), reused 27 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 1.25 MiB | 4.63 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# /content/Hybrid-Quantum-Transformer

# %%
# !pip install pennylane torch torchvision torchaudio matplotlib numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 85.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 937.5/937.5 kB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 70.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 88.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 kB 21.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 117.6 MB/s eta 0:00:00
# ...

# %%
import torch
import pennylane as qml

print(torch.__version__)
print(qml.__version__)
# Out:
# 2.11.0+cpu
# 0.45.0

# %%
# !python train_and_benchmark.py
# Out:
# ...
# STAGE 3: Testing Quantum Circuit
# ...
# Inputs: tensor([ 1.3525,  0.6863, -0.3278,  0.7950])
# Weights shape: torch.Size([2, 4, 3])
# Quantum Circuit Output: [tensor(0.4339, dtype=torch.float64), tensor(0.0637, dtype=torch.float64), tensor(0.1177, dtype=torch.float64), tensor(-0.1123, dtype=torch.float64)]
#
# ...
# STAGE 4: Testing PyTorch Wrapped Quantum Layer
# ...
# Input: tensor([ 0.1498, -0.2089, -0.3870,  0.9912])
# TorchLayer Output: tensor([ 0.4911, -0.0900, -0.0268, -0.0708], grad_fn=<ToCopyBackward0>)
# TorchLayer Output shape: torch.Size([4]) (acts like nn.Linear)
# ...
#
# Using device: cpu
# Vocab size: 58
#
# Classical Transformer Parameters: 18586
#
# Training Classical Transformer...
# Epoch 1 | Train Loss: 4.0318 | Val Loss: 3.9059 | Val Perplexity: 49.6963 | Time: 0.14s
# Epoch 2 | Train Loss: 3.7369 | Val Loss: 3.6769 | Val Perplexity: 39.5233 | Time: 0.07s
# Epoch 3 | Train Loss: 3.4729 | Val Loss: 3.5168 | Val Perplexity: 33.6760 | Time: 0.08s
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("results_comparison.png")

plt.figure(figsize=(12,8))
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(4499.5), np.float64(3599.5), np.float64(-0.5))

# %%
# !mkdir results
# !cp results_comparison.png results/
